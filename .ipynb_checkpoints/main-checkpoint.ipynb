# %% [markdown]
# # Project 001 UCSD Data Science Visualization Bootcamp
# * Noreen Malik 😃
# * Rene Venema("dutch") 🐱
# * John Warlop 🦁
# * Alex Wooten 🏄
#
# 😛😳😗😓🙉😸🙈🙊😽💀💢💥✨💏👫👄👃👀👛👛🗼🔮🔮🎄🎅👻

# %% [markdown]
# ## Dependencies -- imports

# %%
import pandas as pd
from sodapy import Socrata #pip install socrata
import plotly.plotly as py #pip installl plotly
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
import json
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Constants -- API Keys, etc

# %%
# Read in API(.gitignore file has entry for api_keys.json file)
API_endpoint = "https://data.cms.gov/resource/spmh-qjdv.json" #2015 data


IRS_DATAFRAME_PICKLE = 'df_irs.pkl'
with open('api_keys.json') as json_data:
    api_keys = json.load(json_data)

# Socrata Section
socrata_domain = "data.cms.gov"
socrata_dataset_identifier = "spmh-qjdv"
socrata_token = api_keys['socrata']['App_Token']
#print(api_keys['socrata']['App_Token'])
#print(api_keys['socrata']['Secret_Token'])
#print(api_keys['zillow']['ZWSID'])

# %% [markdown]
# ## Functions

# %%
def return_irs_df(file_name):
    #return the pickled dataframe for irs data
    df_irs = pd.read_pickle(file_name)
    return(df_irs)

# %% [markdown]
# # IRS Dataframe
# [Link to Documentation](https://www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-2015-zip-code-data-soi) |
# [SOI Tax Stats](https://www.irs.gov/statistics/soi-tax-stats-statistical-methodology) | [Data Cleaning of IRS Data](https://docs.google.com/document/d/1kNd1S_Ufgy0pIjJSjLDHba8y-pK8OYe47iAGeamH04E/edit?usp=sharing)

# %%
# Dataframe columns are: ST(State), Zip(Zip Code), AGI(Adjusted Gross Income),TtlR(Total Returns)
# TtlSR(Total Single Returns), TtlJR(Total Joint Returns), Eld(Number of Elderly Returns -- over 60 years old)
# AGI column is agreegated: 
# 1=> [1-25000), 2=> [25000-50000), 3=> [50000-75000), 4=> [75000-100000),
# 5=> [100000,200000), 6=> [200000-]
df_irs = return_irs_df(IRS_DATAFRAME_PICKLE)
df_irs.columns
# Out:
# Index(['ST', 'Zip', 'AGI', 'TtlR', 'TtlSR', 'TtlJR', 'Eld'], dtype='object')

# %% [markdown]
# # Dataframe - Medicare csv/api (dutch)
# [Link to Documentation](https://dev.socrata.com/foundry/data.cms.gov/ehrv-m9r6)

# %%
#main_df = pd.read_csv("main_data_cleaned.csv")
#main_df.head()
client = Socrata(socrata_domain, socrata_token)
results = client.get(socrata_dataset_identifier, limit = 100000000) #default for limit (integer) = 1000
main_df = pd.DataFrame.from_dict(results)
main_df.head()
# Convert column datatypes
## Convert to float
col1 = ["average_covered_charges","average_medicare_payments","average_total_payments"]
main_df[col1] = main_df[col1].astype("float")
## Convert to integer
col2 = ["provider_id","provider_zip_code","total_discharges"]
main_df[col2] = main_df[col2].astype("int")
# Export data to csv file
main_df.to_csv("main data cleaned.csv", encoding = "utf-8-sig", index = False)

# %%
# Import data from csv
main_df = pd.read_csv("main data cleaned.csv")

# %% [markdown]
# # Avg Cost Per Provider (Alex)

# %%
# ACC = Average Covered Charges
#     The provider's average charge for services covered by Medicare for all discharges
#     in the DRG. These will vary from
#     hospital to hospital because of differences in hospital charge structures.
# ATP = Average Total Payments
#     The average of Medicare payments to the provider for the DRG including the
#     DRG amount, teaching,  disproportionate 
#     share, capital, and outlier payments for all cases. Also included 
#     are co-payment and deductible amounts that the 
#     patient is responsible for (average_medicare_payments)
# AMP = Average Medicare Payments
#     average_medicare_payments_2?
#     Not sure what this column represents


# Create a Groupby based on Provider Id and Provider name
# Calculate mean values in ACC, ATP, AMP (or we may just be interested in what
# the patient pays)
# I could also sum up the average value of payments by patient and by insurance
# to see average total value provider charges

cost_df = main_df[["provider_id", "provider_name", "average_covered_charges",\
                   "average_total_payments", "average_medicare_payments"]]

provider_group = cost_df.groupby(["provider_id", "provider_name"])
avg_cost_group = round(provider_group.mean(),2)
avg_cost_group.columns
# Out:
# Index(['average_covered_charges', 'average_total_payments',
#        'average_medicare_payments'],
#       dtype='object')

# %%
# Most Expensive Hospitals

# avg_cost_group["Charge Per Patient"] = avg_cost_group[["average_total_payments", "average_medicare_payments"]].diff(axis=1)


avg_cost_group["average_patient_payment"] = (avg_cost_group["average_total_payments"]-
                                             avg_cost_group["average_medicare_payments"])
avg_cost_group.sort_values(by=["average_patient_payment"], ascending=False)
# Out:
#                                                                 average_covered_charges  \
# provider_id provider_name
# 140100      MIDWESTERN REGION MED CENTER                                      109464.69
# 670092      WALNUT HILL MEDICAL CENTER                                         62346.49
# 110233      SOUTHEASTERN REGIONAL MEDICAL CENTER                              109810.08
# 50541       KAISER FOUNDATION HOSPITAL - REDWOOD CITY                          44147.75
# 670096      BAY AREA REGIONAL MEDICAL CENTER, LLC                              45476.72
# 50139       KAISER FOUNDATION HOSPITAL - DOWNEY                                43683.53
# 450874      BAYLOR SURGICAL HOSPITAL AT LAS COLINAS                            61844.35
# 50070       KAISER FOUNDATION HOSPITAL - SOUTH SAN FRANCISCO                   44787.26
# 50076       KAISER FOUNDATION HOSPITAL - SAN FRANCISCO                         54362.29
# 50677       KAISER FOUNDATION HOSPITAL - WOODLAND HILLS                        36599.82
# 50690       KAISER FOUNDATION HOSPITAL-SANTA ROSA                              51476.74
# 280133      NEBRASKA SPINE HOSPITAL, LLC                                      106007.50
# 50071       KAISER FOUNDATION HOSPITAL-SANTA CLARA                             45034.20
# 390312      CANCER TREATMENT CENTERS OF AMERICA                                57897.44
# 670046      USMD HOSPITAL  AT FORT WORTH LP                                    64132.71
# 90004       MEDSTAR GEORGETOWN UNIVERSITY HOSPITAL                            102225.24
# 670073      METHODIST HOSPITAL FOR SURGERY                                     54259.76
# 50767       KAISER FOUNDATION HOSPITAL - VACAVILLE                             46399.54
# 50748       KAISER FOUNDATION HOSPITAL MANTECA                                 45297.86
# 100151      MAYO CLINIC                                                        65434.47
# 50262       RONALD REAGAN U C L A MEDICAL CENTER                              120764.82
# 500008      UNIVERSITY OF WASHINGTON MEDICAL CTR                               76232.72
# 50137       KAISER FOUNDATION HOSPITAL - PANORAMA CITY                         33103.01
# 390027      TEMPLE UNIVERSITY HOSPITAL                                        207950.20
# 390111      HOSPITAL OF UNIV OF PENNSYLVANIA                                  162397.66
# 110200      NORTHSIDE MEDICAL CENTER                                           89537.56
# 230046      UNIVERSITY OF MICHIGAN HEALTH SYSTEM                               74476.13
# 50609       KAISER FOUNDATION HOSPITAL - ORANGE COUNTY - ANAHE                 34423.61
# 450213      UNIVERSITY HEALTH SYSTEM                                           60905.60
# 120011      KAISER FOUNDATION HOSPITAL                                         21284.24
# ...                                                                                 ...
# 70040       HEBREW HOME AND HOSPITAL INC                                        5561.36
# 230301      OAKLAND REGIONAL HOSPITAL                                           9186.16
# 10138       HILL HOSPITAL OF SUMTER COUNTY                                     10279.97
# 190190      CALDWELL MEMORIAL HOSPITAL, INC                                    10777.60
# 490002      RUSSELL COUNTY MEDICAL CENTER                                      19217.30
# 40011       CHAMBERS MEMORIAL HOSPITAL                                          6108.05
# 430084      PHS INDIAN HOSPITAL AT ROSEBUD                                      9274.50
# 450214      GULF COAST MEDICAL CENTER                                          27752.02
# 50205       GLENDORA COMMUNITY HOSPITAL                                        29806.53
# 330053      MEDINA MEMORIAL HOSPITAL                                           11106.25
# 250049      BEACHAM MEMORIAL HOSPITAL                                           6176.23
# 50547       SONOMA DEVELOPMENTAL CENTER                                        30742.21
# 390278      EAGLEVILLE HOSPITAL                                                 5127.07
# 450497      BOWIE MEMORIAL HOSPITAL                                            20153.08
# 390025      KENSINGTON HOSPITAL                                                 5699.35
# 370072      LATIMER COUNTY GENERAL HOSPITAL                                     8762.38
# 440159      DELTA MEDICAL CENTER                                               28575.06
# 100322      REGIONAL GENERAL HOSPITAL WILLISTON                                10731.85
# 440070      DECATUR COUNTY GENERAL HOSPITAL                                     6894.42
# 370051      MEMORIAL HOSPITAL & PHYSICIAN GROUP                                 6686.53
# 110113      BURKE MEDICAL CENTER                                               17516.83
# 370057      MUSCOGEE (CREEK) NATION MEDICAL CENTER                              9399.43
# 440181      BOLIVAR GENERAL HOSPITAL                                            7237.85
# 30132       FLORENCE HOSPITAL AT ANTHEM, LLC                                   39172.13
# 330406      SUNNYVIEW HOSPITAL AND REHABILITATION CENTER                       15969.44
# 670050      TRUSTPOINT REHAB HOSPITAL OF LUBBOCK                               15089.77
# 110209      TURNING POINT HOSPITAL                                              3375.67
# 50546       PORTERVILLE DEVELOPMENTAL CENTER                                   45241.12
# 330404      WINIFRED MASTERSON BURKE REHABILITATION HOSPITAL                   20301.93
# 330405      HELEN HAYES HOSPITAL                                               16257.79
#
#                                                                 average_total_payments  \
# provider_id provider_name
# 140100      MIDWESTERN REGION MED CENTER                                      49820.77
# 670092      WALNUT HILL MEDICAL CENTER                                        37598.19
# 110233      SOUTHEASTERN REGIONAL MEDICAL CENTER                              38391.15
# 50541       KAISER FOUNDATION HOSPITAL - REDWOOD CITY                         25823.96
# 670096      BAY AREA REGIONAL MEDICAL CENTER, LLC                             18572.35
# 50139       KAISER FOUNDATION HOSPITAL - DOWNEY                               20051.57
# 450874      BAYLOR SURGICAL HOSPITAL AT LAS COLINAS                           25188.84
# 50070       KAISER FOUNDATION HOSPITAL - SOUTH SAN FRANCISCO                  20319.47
# 50076       KAISER FOUNDATION HOSPITAL - SAN FRANCISCO                        22719.93
# 50677       KAISER FOUNDATION HOSPITAL - WOODLAND HILLS                       17679.88
# 50690       KAISER FOUNDATION HOSPITAL-SANTA ROSA                             20150.70
# 280133      NEBRASKA SPINE HOSPITAL, LLC                                      30678.27
# 50071       KAISER FOUNDATION HOSPITAL-SANTA CLARA                            18567.64
# 390312      CANCER TREATMENT CENTERS OF AMERICA                               13377.94
# 670046      USMD HOSPITAL  AT FORT WORTH LP                                   17581.98
# 90004       MEDSTAR GEORGETOWN UNIVERSITY HOSPITAL                            28604.05
# 670073      METHODIST HOSPITAL FOR SURGERY                                    26404.59
# 50767       KAISER FOUNDATION HOSPITAL - VACAVILLE                            18228.63
# 50748       KAISER FOUNDATION HOSPITAL MANTECA                                17143.70
# 100151      MAYO CLINIC                                                       23457.88
# 50262       RONALD REAGAN U C L A MEDICAL CENTER                              41785.63
# 500008      UNIVERSITY OF WASHINGTON MEDICAL CTR                              32135.60
# 50137       KAISER FOUNDATION HOSPITAL - PANORAMA CITY                        15340.01
# 390027      TEMPLE UNIVERSITY HOSPITAL                                        34393.60
# 390111      HOSPITAL OF UNIV OF PENNSYLVANIA                                  31170.92
# 110200      NORTHSIDE MEDICAL CENTER                                          23148.24
# 230046      UNIVERSITY OF MICHIGAN HEALTH SYSTEM                              28186.03
# 50609       KAISER FOUNDATION HOSPITAL - ORANGE COUNTY - ANAHE                14538.78
# 450213      UNIVERSITY HEALTH SYSTEM                                          25771.12
# 120011      KAISER FOUNDATION HOSPITAL                                        14082.21
# ...                                                                                ...
# 70040       HEBREW HOME AND HOSPITAL INC                                       5092.15
# 230301      OAKLAND REGIONAL HOSPITAL                                          6381.86
# 10138       HILL HOSPITAL OF SUMTER COUNTY                                     5317.60
# 190190      CALDWELL MEMORIAL HOSPITAL, INC                                    5145.94
# 490002      RUSSELL COUNTY MEDICAL CENTER                                      5836.19
# 40011       CHAMBERS MEMORIAL HOSPITAL                                         5350.98
# 430084      PHS INDIAN HOSPITAL AT ROSEBUD                                     9618.42
# 450214      GULF COAST MEDICAL CENTER                                          9339.24
# 50205       GLENDORA COMMUNITY HOSPITAL                                        8746.29
# 330053      MEDINA MEMORIAL HOSPITAL                                          10856.50
# 250049      BEACHAM MEMORIAL HOSPITAL                                          5509.11
# 50547       SONOMA DEVELOPMENTAL CENTER                                       11726.68
# 390278      EAGLEVILLE HOSPITAL                                                6322.68
# 450497      BOWIE MEMORIAL HOSPITAL                                            5860.97
# 390025      KENSINGTON HOSPITAL                                               24816.65
# 370072      LATIMER COUNTY GENERAL HOSPITAL                                    6013.47
# 440159      DELTA MEDICAL CENTER                                               9718.16
# 100322      REGIONAL GENERAL HOSPITAL WILLISTON                                4196.69
# 440070      DECATUR COUNTY GENERAL HOSPITAL                                    5448.28
# 370051      MEMORIAL HOSPITAL & PHYSICIAN GROUP                                6265.33
# 110113      BURKE MEDICAL CENTER                                               7646.50
# 370057      MUSCOGEE (CREEK) NATION MEDICAL CENTER                             5483.67
# 440181      BOLIVAR GENERAL HOSPITAL                                           5235.91
# 30132       FLORENCE HOSPITAL AT ANTHEM, LLC                                  11657.93
# 330406      SUNNYVIEW HOSPITAL AND REHABILITATION CENTER                       5868.05
# 670050      TRUSTPOINT REHAB HOSPITAL OF LUBBOCK                               5646.50
# 110209      TURNING POINT HOSPITAL                                             3991.80
# 50546       PORTERVILLE DEVELOPMENTAL CENTER                                   4704.41
# 330404      WINIFRED MASTERSON BURKE REHABILITATION HOSPITAL                   8095.22
# 330405      HELEN HAYES HOSPITAL                                               7781.11
#
#                                                                 average_medicare_payments  \
# provider_id provider_name
# 140100      MIDWESTERN REGION MED CENTER                                         13068.77
# 670092      WALNUT HILL MEDICAL CENTER                                            8486.33
# 110233      SOUTHEASTERN REGIONAL MEDICAL CENTER                                 20501.54
# 50541       KAISER FOUNDATION HOSPITAL - REDWOOD CITY                            10467.44
# 670096      BAY AREA REGIONAL MEDICAL CENTER, LLC                                 6051.55
# 50139       KAISER FOUNDATION HOSPITAL - DOWNEY                                   8202.54
# 450874      BAYLOR SURGICAL HOSPITAL AT LAS COLINAS                              13449.23
# 50070       KAISER FOUNDATION HOSPITAL - SOUTH SAN FRANCISCO                      8637.25
# 50076       KAISER FOUNDATION HOSPITAL - SAN FRANCISCO                           11742.60
# 50677       KAISER FOUNDATION HOSPITAL - WOODLAND HILLS                           7226.63
# 50690       KAISER FOUNDATION HOSPITAL-SANTA ROSA                                10257.19
# 280133      NEBRASKA SPINE HOSPITAL, LLC                                         20907.35
# 50071       KAISER FOUNDATION HOSPITAL-SANTA CLARA                                8889.46
# 390312      CANCER TREATMENT CENTERS OF AMERICA                                   4259.50
# 670046      USMD HOSPITAL  AT FORT WORTH LP                                       8586.05
# 90004       MEDSTAR GEORGETOWN UNIVERSITY HOSPITAL                               19719.81
# 670073      METHODIST HOSPITAL FOR SURGERY                                       17565.46
# 50767       KAISER FOUNDATION HOSPITAL - VACAVILLE                                9469.70
# 50748       KAISER FOUNDATION HOSPITAL MANTECA                                    8418.17
# 100151      MAYO CLINIC                                                          14896.47
# 50262       RONALD REAGAN U C L A MEDICAL CENTER                                 33625.20
# 500008      UNIVERSITY OF WASHINGTON MEDICAL CTR                                 24300.46
# 50137       KAISER FOUNDATION HOSPITAL - PANORAMA CITY                            7514.62
# 390027      TEMPLE UNIVERSITY HOSPITAL                                           26580.12
# 390111      HOSPITAL OF UNIV OF PENNSYLVANIA                                     23433.34
# 110200      NORTHSIDE MEDICAL CENTER                                             15444.52
# 230046      UNIVERSITY OF MICHIGAN HEALTH SYSTEM                                 20662.68
# 50609       KAISER FOUNDATION HOSPITAL - ORANGE COUNTY - ANAHE                    7022.00
# 450213      UNIVERSITY HEALTH SYSTEM                                             18259.64
# 120011      KAISER FOUNDATION HOSPITAL                                            6629.77
# ...                                                                                   ...
# 70040       HEBREW HOME AND HOSPITAL INC                                          4310.22
# 230301      OAKLAND REGIONAL HOSPITAL                                             5601.88
# 10138       HILL HOSPITAL OF SUMTER COUNTY                                        4540.48
# 190190      CALDWELL MEMORIAL HOSPITAL, INC                                       4370.30
# 490002      RUSSELL COUNTY MEDICAL CENTER                                         5061.44
# 40011       CHAMBERS MEMORIAL HOSPITAL                                            4578.53
# 430084      PHS INDIAN HOSPITAL AT ROSEBUD                                        8848.12
# 450214      GULF COAST MEDICAL CENTER                                             8572.63
# 50205       GLENDORA COMMUNITY HOSPITAL                                           7985.64
# 330053      MEDINA MEMORIAL HOSPITAL                                             10110.83
# 250049      BEACHAM MEMORIAL HOSPITAL                                             4764.29
# 50547       SONOMA DEVELOPMENTAL CENTER                                          10982.95
# 390278      EAGLEVILLE HOSPITAL                                                   5587.64
# 450497      BOWIE MEMORIAL HOSPITAL                                               5133.09
# 390025      KENSINGTON HOSPITAL                                                  24106.39
# 370072      LATIMER COUNTY GENERAL HOSPITAL                                       5304.28
# 440159      DELTA MEDICAL CENTER                                                  9018.74
# 100322      REGIONAL GENERAL HOSPITAL WILLISTON                                   3525.00
# 440070      DECATUR COUNTY GENERAL HOSPITAL                                       4785.70
# 370051      MEMORIAL HOSPITAL & PHYSICIAN GROUP                                   5605.07
# 110113      BURKE MEDICAL CENTER                                                  6989.17
# 370057      MUSCOGEE (CREEK) NATION MEDICAL CENTER                                4859.90
# 440181      BOLIVAR GENERAL HOSPITAL                                              4646.43
# 30132       FLORENCE HOSPITAL AT ANTHEM, LLC                                     11081.67
# 330406      SUNNYVIEW HOSPITAL AND REHABILITATION CENTER                          5309.62
# 670050      TRUSTPOINT REHAB HOSPITAL OF LUBBOCK                                  5105.44
# 110209      TURNING POINT HOSPITAL                                                3503.85
# 50546       PORTERVILLE DEVELOPMENTAL CENTER                                      4263.10
# 330404      WINIFRED MASTERSON BURKE REHABILITATION HOSPITAL                      7948.22
# 330405      HELEN HAYES HOSPITAL                                                  7684.49
#
#                                                                 average_patient_payment
# provider_id provider_name
# 140100      MIDWESTERN REGION MED CENTER                                       36752.00
# 670092      WALNUT HILL MEDICAL CENTER                                         29111.86
# 110233      SOUTHEASTERN REGIONAL MEDICAL CENTER                               17889.61
# 50541       KAISER FOUNDATION HOSPITAL - REDWOOD CITY                          15356.52
# 670096      BAY AREA REGIONAL MEDICAL CENTER, LLC                              12520.80
# 50139       KAISER FOUNDATION HOSPITAL - DOWNEY                                11849.03
# 450874      BAYLOR SURGICAL HOSPITAL AT LAS COLINAS                            11739.61
# 50070       KAISER FOUNDATION HOSPITAL - SOUTH SAN FRANCISCO                   11682.22
# 50076       KAISER FOUNDATION HOSPITAL - SAN FRANCISCO                         10977.33
# 50677       KAISER FOUNDATION HOSPITAL - WOODLAND HILLS                        10453.25
# 50690       KAISER FOUNDATION HOSPITAL-SANTA ROSA                               9893.51
# 280133      NEBRASKA SPINE HOSPITAL, LLC                                        9770.92
# 50071       KAISER FOUNDATION HOSPITAL-SANTA CLARA                              9678.18
# 390312      CANCER TREATMENT CENTERS OF AMERICA                                 9118.44
# 670046      USMD HOSPITAL  AT FORT WORTH LP                                     8995.93
# 90004       MEDSTAR GEORGETOWN UNIVERSITY HOSPITAL                              8884.24
# 670073      METHODIST HOSPITAL FOR SURGERY                                      8839.13
# 50767       KAISER FOUNDATION HOSPITAL - VACAVILLE                              8758.93
# 50748       KAISER FOUNDATION HOSPITAL MANTECA                                  8725.53
# 100151      MAYO CLINIC                                                         8561.41
# 50262       RONALD REAGAN U C L A MEDICAL CENTER                                8160.43
# 500008      UNIVERSITY OF WASHINGTON MEDICAL CTR                                7835.14
# 50137       KAISER FOUNDATION HOSPITAL - PANORAMA CITY                          7825.39
# 390027      TEMPLE UNIVERSITY HOSPITAL                                          7813.48
# 390111      HOSPITAL OF UNIV OF PENNSYLVANIA                                    7737.58
# 110200      NORTHSIDE MEDICAL CENTER                                            7703.72
# 230046      UNIVERSITY OF MICHIGAN HEALTH SYSTEM                                7523.35
# 50609       KAISER FOUNDATION HOSPITAL - ORANGE COUNTY - ANAHE                  7516.78
# 450213      UNIVERSITY HEALTH SYSTEM                                            7511.48
# 120011      KAISER FOUNDATION HOSPITAL                                          7452.44
# ...                                                                                 ...
# 70040       HEBREW HOME AND HOSPITAL INC                                         781.93
# 230301      OAKLAND REGIONAL HOSPITAL                                            779.98
# 10138       HILL HOSPITAL OF SUMTER COUNTY                                       777.12
# 190190      CALDWELL MEMORIAL HOSPITAL, INC                                      775.64
# 490002      RUSSELL COUNTY MEDICAL CENTER                                        774.75
# 40011       CHAMBERS MEMORIAL HOSPITAL                                           772.45
# 430084      PHS INDIAN HOSPITAL AT ROSEBUD                                       770.30
# 450214      GULF COAST MEDICAL CENTER                                            766.61
# 50205       GLENDORA COMMUNITY HOSPITAL                                          760.65
# 330053      MEDINA MEMORIAL HOSPITAL                                             745.67
# 250049      BEACHAM MEMORIAL HOSPITAL                                            744.82
# 50547       SONOMA DEVELOPMENTAL CENTER                                          743.73
# 390278      EAGLEVILLE HOSPITAL                                                  735.04
# 450497      BOWIE MEMORIAL HOSPITAL                                              727.88
# 390025      KENSINGTON HOSPITAL                                                  710.26
# 370072      LATIMER COUNTY GENERAL HOSPITAL                                      709.19
# 440159      DELTA MEDICAL CENTER                                                 699.42
# 100322      REGIONAL GENERAL HOSPITAL WILLISTON                                  671.69
# 440070      DECATUR COUNTY GENERAL HOSPITAL                                      662.58
# 370051      MEMORIAL HOSPITAL & PHYSICIAN GROUP                                  660.26
# 110113      BURKE MEDICAL CENTER                                                 657.33
# 370057      MUSCOGEE (CREEK) NATION MEDICAL CENTER                               623.77
# 440181      BOLIVAR GENERAL HOSPITAL                                             589.48
# 30132       FLORENCE HOSPITAL AT ANTHEM, LLC                                     576.26
# 330406      SUNNYVIEW HOSPITAL AND REHABILITATION CENTER                         558.43
# 670050      TRUSTPOINT REHAB HOSPITAL OF LUBBOCK                                 541.06
# 110209      TURNING POINT HOSPITAL                                               487.95
# 50546       PORTERVILLE DEVELOPMENTAL CENTER                                     441.31
# 330404      WINIFRED MASTERSON BURKE REHABILITATION HOSPITAL                     147.00
# 330405      HELEN HAYES HOSPITAL                                                  96.62
#
# [3231 rows x 4 columns]

# %% [markdown]
# # Avg Cost of Procedure in each state(John)

# %%
#main_df['ACC'].groupby(main_df['Provider State']).head()
#state_office = df.groupby(['state', 'office_id']).agg({'sales': 'sum'})
#main_df.rename(columns = {list(main_df)[8]: 'TtlDis'}, inplace = True)
df_costs = main_df.groupby(['provider_state']).\
            aggregate({'average_covered_charges':'sum',\
                       'average_total_payments':'sum','total_discharges':'sum'})
df_costs['Ttl_billed_per_p']  = (df_costs['average_covered_charges']+df_costs['average_total_payments'])\
                                /df_costs['total_discharges']
df_costs['Ttl_covered_per_p'] =  df_costs['average_covered_charges']/df_costs['total_discharges']
df_costs['Ttl_oop_per_p'] = df_costs['average_total_payments']/df_costs['total_discharges']
df_costs.columns
#df_acc = main_df.groupby(['Provider State']).aggregate({'ACC':'sum'})
#df_atp = main_df.groupby(['Provider State']).aggregate({'ATP':'sum'})
#df_ttlD = main_df.groupby(['Provider State']).aggregate({'TtlDis':'sum'})
#df_ttlD.iloc[:,0:]

# %% [markdown]
# # Comparing procedure costs vs income in zip code(John)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Dutch

# %%
# Unique DRG definitions
main_df["drg_definition"].nunique()

# %%
# Unique HRR Descriptions
main_df["hospital_referral_region_hrr_description"].nunique()

# %%
# Unique providers
main_df["provider_id"].nunique()# Unique states (including the federal district D.C. (Washington D.C.))
main_df["provider_state"].nunique()

# %%
# Providers per state
main_df.groupby("provider_state")["provider_id"].nunique()

# %%
# US state map
## Total ACC, ATP and AMP by provider state
state_totals_df = main_df.groupby("provider_state", as_index = False).agg({"provider_id":"nunique",
                                                                           "average_covered_charges":"sum",
                                                                           "average_medicare_payments":"sum",
                                                                           "average_total_payments":"sum"})

cols = ["average_covered_charges","average_medicare_payments","average_total_payments"]
state_totals_df[cols] = state_totals_df[cols]/1000000

state_totals_df = state_totals_df.rename(columns={"provider_state":"State",
                                                  "provider_id":"Total providers",
                                                  "average_covered_charges":"ACC Total",
                                                  "average_medicare_payments":"AMP Total",
                                                  "average_total_payments":"ATP Total"
                                                 })

state_totals_df.head()

for col in state_totals_df.columns:
    state_totals_df[col] = state_totals_df[col].astype(str)

# %%
scl = [[0.0, "rgb(242,240,247)"],[0.2, "rgb(218,218,235)"],[0.4, "rgb(188,189,220)"],
            [0.6, "rgb(158,154,200)"],[0.8, "rgb(117,107,177)"],[1.0, "rgb(84,39,143)"]]

# %%
state_totals_df['text'] = state_totals_df["State"] + '<br>' +\
    "ACC"+state_totals_df["ACC Total"]+' AMP '+state_totals_df["AMP Total"]+'<br>'+\
    'ATP '+state_totals_df["ATP Total"]

# %%
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = state_totals_df["State"],
        z = state_totals_df["Total providers"].astype(float),
        locationmode = 'USA-states',
        text = state_totals_df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Millions USD")
        ) ]

layout = dict(
        title = '2015 US Medicare inpatient charges and payments by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
iplot( fig, filename='d3-cloropleth-map' )
